# %%
from google.colab import userdata
import os

os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")

print("API key loaded successfully!")
# Out:
# API key loaded successfully!

# %% [markdown]
# # Install libraries

# %%
# !pip install -q youtube-transcript-api langchain-community langchain-google-genai faiss-cpu python-dotenv

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api._errors import TranscriptsDisabled
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# ### Step 1a -Indexing (Document lngestion):

# %%
video_id = "LPZh9BOjkQs"

try:
    ytt_api = YouTubeTranscriptApi()

    transcript = ytt_api.fetch(
        video_id,
        languages=["en"]
    )

    # Convert transcript snippets to plain text
    transcript_text = " ".join(
        snippet.text for snippet in transcript
    )

    print(transcript_text)

except TranscriptsDisabled:
    print("Transcript is disabled for this video.")
# Out:
# ---------------------------------------------------------------------------
# RequestBlocked                            Traceback (most recent call last)
# /tmp/ipykernel_9330/1597059583.py in <cell line: 0>()
#       4     ytt_api = YouTubeTranscriptApi()
#       5
# ----> 6     transcript = ytt_api.fetch(
#       7         video_id,
#       8         languages=["en"]
#
# /usr/local/lib/python3.13/dist-packages/youtube_transcript_api/_api.py in fetch(self, video_id, languages, preserve_formatting)
#      69         """
#      70         return (
# ---> 71             self.list(video_id)
#      72             .find_transcript(languages)
#      73             .fetch(preserve_formatting=preserve_formatting)
#
# /usr/local/lib/python3.13/dist-packages/youtube_transcript_api/_api.py in list(self, video_id)
#     125             Make sure that this is the actual ID, NOT the full URL to the video!
#     126         """
# --> 127         return self._fetcher.fetch(video_id)
#
# ...
