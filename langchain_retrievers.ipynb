# %%
from google.colab import userdata
import os

os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")

print("API key loaded successfully!")
# Out:
# API key loaded successfully!

# %%
# !pip install -U langchain-google-genai

# %%
from google.colab import userdata
import os

from langchain_google_genai import ChatGoogleGenerativeAI


# Load API key from Colab Secrets
os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")


# Create Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    google_api_key=os.environ["GEMINI_API_KEY"],
    max_retries=3
)


# Test Gemini
response = llm.invoke(
    "What is a vector database?"
)

print(response.content)
# Out:
# [{'type': 'text', 'text': 'A **vector database** is a specialized type of database designed to store, manage, and search **high-dimensional vectors** (often called *embeddings*). \n\nUnlike traditional databases that search for exact matches (like matching a customer ID or a specific keyword), vector databases are built to search for **similarity** based on context and meaning.\n\nVector databases have gained massive popularity alongside the rise of Artificial Intelligence (AI) and Large Language Models (LLMs) like ChatGPT.\n\n---\n\n### 1. The Core Concept: What is a Vector?\n\nTo understand vector databases, you first need to understand **vector embeddings**:\n\n1. **Unstructured Data:** Most real-world data is unstructured—text, images, audio, video, and PDF files.\n2. **Translation into Numbers:** AI models (like OpenAI’s text-embedding models or CLIP for images) convert this unstructured data into long arrays of numbers called **vectors** or **embeddings** (e.g., `[0.12, -0.45, 
# ...

# %%
response = llm.invoke(
    "Explain RAG in one sentence."
)

print(response.content)
# Out:
# [{'type': 'text', 'text': '**Retrieval-Augmented Generation (RAG)** is an AI technique that enhances large language models by searching an external knowledge base for relevant facts and using that retrieved information to generate more accurate, up-to-date, and context-aware responses.', 'extras': {'signature': '...'}}]

# %%
response = llm.invoke(
    """
    Explain Contextual Compression Retriever in LangChain.
    Keep the explanation under 100 words.
    """
)

print(response.content)
# Out:
# [{'type': 'text', 'text': 'Standard vector retrievers often return full document chunks that contain irrelevant noise, wasting tokens and distracting the LLM. \n\nLangChain’s **Contextual Compression Retriever** solves this by combining a base retriever with a document compressor. \n\n**How it works:**\n1. **Retrieve:** The base retriever fetches initial document chunks related to the query.\n2. **Compress:** A compressor (using an LLM or embeddings model) extracts only the query-relevant sentences or drops irrelevant documents entirely.\n\nThis reduces context window size, lowers token costs, and improves answer accuracy by passing only concise, highly relevant information to the LLM.', 'extras': {'signature': '...'}}]

# %% [markdown]
# # ContextualCompressionRetriever

# %%
# !pip install -U langchain langchain-community langchain-google-genai
# !pip install -U langchain-huggingface sentence-transformers faiss-cpu
# !pip install -U langchain-classic
# Out:
# ...
#   Using cached sentence_transformers-6.0.0-py3-none-any.whl.metadata (20 kB)
# ...
# Using cached sentence_transformers-6.0.0-py3-none-any.whl (739 kB)
# ...
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 5.7.0
#     Uninstalling sentence-transformers-5.7.0:
#       Successfully uninstalled sentence-transformers-5.7.0
# ...

# %%
from google.colab import userdata
import os

os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")

# %%
print("API key loaded:", bool(os.environ.get("GEMINI_API_KEY")))
# Out:
# API key loaded: True

# %% [markdown]
# # Crearte Gemini LLM

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    google_api_key=os.environ["GEMINI_API_KEY"],
    max_retries=3
)

# %% [markdown]
# # We test the gemini LLM to respond

# %%
response = llm.invoke(
    "What is contextual compression retrieval?"
)

print(response.content)
# Out:
# [{'type': 'text', 'text': '**Contextual Compression Retrieval** is an advanced pattern used in Retrieval-Augmented Generation (RAG) systems to improve the quality, accuracy, and efficiency of Large Language Model (LLM) responses.\n\nIn standard RAG, a system fetches entire chunks of text (e.g., 500-word paragraphs) based on semantic similarity to a user\'s prompt. However, much of that retrieved chunk might be irrelevant to the specific question asked.\n\n**Contextual Compression solves this by wrapping a standard retriever with a "compressor" that filters, trims, or transforms the retrieved documents *in the context of the user\'s specific query* before passing them to the LLM.**\n\n---\n\n### The Problem It Solves\n\nStandard RAG faces a few major challenges:\n1. **Noise / Irrelevant Context:** A retrieved chunk might contain 10% useful information and 90% unrelated fluff.\n2. **"Lost in the Middle" Effect:** LLMs tend to pay attention to the beginning and end of a prompt, often mi
# ...

# %%
# let's create documents manually first.

from langchain_core.documents import Document

documents = [
    Document(
        page_content="""
        Python is a high-level, interpreted programming language.
        It is widely used in software development, data science,
        machine learning, artificial intelligence, automation,
        and web development.
        """
    ),

    Document(
        page_content="""
        Machine learning is a branch of artificial intelligence.
        Machine learning algorithms learn patterns from data and
        use those patterns to make predictions or decisions.
        Common machine learning approaches include supervised,
        unsupervised, and reinforcement learning.
        """
    ),

    Document(
        page_content="""
        Deep learning is a subfield of machine learning.
        It uses artificial neural networks containing multiple
        layers to learn complex patterns from large amounts of data.
        Deep learning is commonly used in computer vision,
        natural language processing, speech recognition,
        and generative AI.
        """
    ),

    Document(
        page_content="""
        Islamabad is the capital city of Pakistan.
        It is located near the Margalla Hills and is known for
        its greenery, parks, and modern urban infrastructure.
        """
    ),

    Document(
        page_content="""
        Natural Language Processing, commonly called NLP,
        is a field of artificial intelligence that focuses on
        enabling computers to understand, process, and generate
        human language.
        """
    )
]

# %% [markdown]
# # Create Hugging Face embeddings
#
# Here we are not using Gemini for embeddings.

# %%
# We're keeping the embeddings local:

from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# This model will convert my documents into vectors.
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
# Create the FAISS vector store
from langchain_community.vectorstores import FAISS

vectorstore = FAISS.from_documents(
    documents,
    embeddings
)

# %%
# Create the base retriever
base_retriever = vectorstore.as_retriever(
    search_kwargs={
        "k": 3
    }
)

# %% [markdown]
# # k=3 means:
#  Retrieve the 3 most semantically similar documents for the user's query.

# %%
# Gemini Compressor
from langchain_classic.retrievers.document_compressors import LLMChainExtractor

compressor = LLMChainExtractor.from_llm(
    llm
)

print("Compressor created successfully!")
# Out:
# Compressor created successfully!

# %%
# Create the Contextual Compression Retriever
from langchain_classic.retrievers import ContextualCompressionRetriever

compression_retriever = ContextualCompressionRetriever(
    base_retriever=base_retriever,
    base_compressor=compressor
)

print("Contextual Compression Retriever created successfully!")
# Out:
# Contextual Compression Retriever created successfully!

# %%
query = "What is deep learning?"

compressed_docs = compression_retriever.invoke(query)

print(
    "Number of compressed documents:",
    len(compressed_docs)
)

for i, doc in enumerate(compressed_docs):

    print(f"\n========== Document {i + 1} ==========\n")

    print(doc.page_content)
# Out:
# Number of compressed documents: 1
#
# ========== Document 1 ==========
#
# Deep learning is a subfield of machine learning.
#         It uses artificial neural networks containing multiple
#         layers to learn complex patterns from large amounts of data.

# %%
# !pip install langchain langchain-community langchain-huggingface chromadb faiss-cpu sentence-transformers transformers torch wikipedia
# !pip install requests==2.32.4 opentelemetry-api==1.42.1 opentelemetry-sdk==1.42.1 --quiet
# Out:
# ...
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached opentelemetry_sdk-1.44.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl.metadata (2.4 kB)
# ...
# Using cached opentelemetry_sdk-1.44.0-py3-none-any.whl (137 kB)
# Using cached opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
# Using cached opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl (204 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.42.1
#     Uninstalling opentelemetry-api-1.42.1:
#       Successfully uninstalled opentelemetry-api-1.42.1
# ...

# %% [markdown]
# # Wikipedia Retriever

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
from langchain_community.retrievers import WikipediaRetriever
# Out:
# /tmp/ipykernel_3362/2879121110.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.retrievers import WikipediaRetriever

# %%
# initialize the retriever (optional: set language and top_k)
retriever = WikipediaRetriever(top_k_results=2, lang='en')

# %%
# Define your query
query = 'the geopolitical history of pakistan and india from the perspective of a chinese'

# Get revelant  Wikipedia documents
docs = retriever.invoke(query)

# %%
docs
# Out:
# [Document(metadata={'title': 'India–Pakistan war of 1971', 'summary': "The India–Pakistan war of 1971, also known as the third Indo-Pakistani war, was a military confrontation between India and Pakistan that occurred during the Bangladesh Liberation War in East Pakistan from 3 December 1971 until the Pakistani capitulation in Dhaka on 16 December 1971.  The war began with Pakistan's Operation Chengiz Khan, consisting of preemptive aerial strikes on eight Indian air stations. The strikes led to India declaring war on Pakistan, marking their entry into the war for East Pakistan's independence, on the side of Bengali nationalist forces. India's entry expanded the existing conflict with Indian and Pakistani forces engaging on both the eastern and western fronts.\nThirteen days after the war started, India achieved a clear upper hand, and the Eastern Command of the Pakistan military signed the instrument of surrender on 16 December 1971 in Dhaka, marking the formation of East Pakistan as 
# ...

# %%
# print retrieved content
for i, doc in enumerate(docs):
  print(f"\n--- Result {i+1} ---")
  print(f"content:\n{doc.page_content}...") # truncate for display
# Out:
# --- Result 1 ---
# content:
# The India–Pakistan war of 1971, also known as the third Indo-Pakistani war, was a military confrontation between India and Pakistan that occurred during the Bangladesh Liberation War in East Pakistan from 3 December 1971 until the Pakistani capitulation in Dhaka on 16 December 1971.  The war began with Pakistan's Operation Chengiz Khan, consisting of preemptive aerial strikes on eight Indian air stations. The strikes led to India declaring war on Pakistan, marking their entry into the war for East Pakistan's independence, on the side of Bengali nationalist forces. India's entry expanded the existing conflict with Indian and Pakistani forces engaging on both the eastern and western fronts.
# ...

# %% [markdown]
# # Vector Store Retriever

# %%
from langchain_community.vectorstores import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_core.documents import Document

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
# Step 1: Your source documents
documents = [
    Document(page_content="LangChain helps developers build LLM applictions easily."),
    Document(page_content="Chroma is a vector database optimized for LLM based search."),
    Document(page_content="Embeddings convert text into high-dimensional vectors."),
    Document(page_content="OpenAI Provides powerful embedding models."),
]

# %%
from langchain_core import vectorstores
# Sep 2 : Initialize embedding model
embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Step 3 : Create chroma vector store in memory
vectorstore = Chroma.from_documents(
    documents = documents,
    embedding = embedding_model,
    collection_name = 'my_collection'
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
# Convert Vectorstore into a retriever
retriever = vectorstore.as_retriever(search_type = 'similarity', search_kwargs = {'k': 2})

# %%
query = 'What is Chroma used for?'
results = retriever.invoke(query)

# %%
# print retrieved content
for i, doc in enumerate(results):
  print(f"\n--- Result {i+1} ---")
  print(f"content:\n{doc.page_content}...") # truncate for display
# Out:
# --- Result 1 ---
# content:
# Chroma is a vector database optimized for LLM based search....
#
# --- Result 2 ---
# content:
# LangChain helps developers build LLM applictions easily....

# %%
results = vectorstore.similarity_search(query, k=2)

# %%
# print retrieved content
for i, doc in enumerate(results):
  print(f"\n--- Result {i+1} ---")
  print(f"content:\n{doc.page_content}...") # truncate for display
# Out:
# --- Result 1 ---
# content:
# Chroma is a vector database optimized for LLM based search....
#
# --- Result 2 ---
# content:
# LangChain helps developers build LLM applictions easily....

# %% [markdown]
# # MMR

# %%
# Simple Documents
docs = [
    Document(page_content="LangChain makes it easy to work with LLMs ."),
    Document(page_content="Langchain is used to build LLM based applications."),
    Document(page_content="Chroma is used to store and search document embeddings."),
    Document(page_content="Embeddings are vector representations of text."),
    Document(page_content="MMR helps you get diverse result when doing similarity search."),
    Document(page_content="Langchain supports Chroma,FAISS,Pinecone,and more."),
]

# %%
from langchain_community.vectorstores import FAISS

# Initialize embedding model
embedding_model = HuggingFaceEmbeddings()

# Create the FAISS vector store from documents
vectorstore = FAISS.from_documents(
    documents = docs,
    embedding = embedding_model,
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/11.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  438MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Enable MMR in the retriever
retriever = vectorstore.as_retriever(
    search_type = 'mmr',             # <--- This enables MMR
    search_kwargs = {'k': 3, 'lambda_mult': 0.5}  # k = top results, lambda_mult = relevance-diversity balance
)

# %%
query = 'What is langchain?'
results = retriever.invoke(query)

# %%
# print retrieved content
for i, doc in enumerate(results):
  print(f"\n--- Result {i+1} ---")
  print(f"content:\n{doc.page_content}...") # truncate for display
# Out:
# --- Result 1 ---
# content:
# Langchain is used to build LLM based applications....
#
# --- Result 2 ---
# content:
# Embeddings are vector representations of text....
#
# --- Result 3 ---
# content:
# Langchain supports Chroma,FAISS,Pinecone,and more....

# %% [markdown]
# # Multi query retriever

# %%
# %pip install -U langchain-community
# !pip install -U langchain-huggingface "transformers<5"
# %pip install -U faiss-cpu
# !pip install -qU langchain-huggingface sentence-transformers faiss-cpu
# Out:
# ...
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# ...
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 642.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 46.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 36.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.27.0
#     Uninstalling huggingface_hub-1.27.0:
# ...

# %%
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFacePipeline, ChatHuggingFace
from langchain_core.documents import Document
from langchain_huggingface import ChatHuggingFace
from langchain_classic.retrievers import MultiQueryRetriever

# %%
# Relevant health & wellness documents
all_docs = [
    Document(page_content="Regular walking boosts heart health and can reduce symptoms of depression.", metadata={"source": "H1"}),
    Document(page_content="Consuming leafy greens and fruits helps detox the body and improve longevity.", metadata={"source": "H2"}),
    Document(page_content="Deep sleep is crucial for cellular repair and emotional regulation.", metadata={"source": "H3"}),
    Document(page_content="Mindfulness and controlled breathing lower cortisol and improve mental clarity.", metadata={"source": "H4"}),
    Document(page_content="Drinking sufficient water throughout the day helps maintain metabolism and energy.", metadata={"source": "H5"}),
    Document(page_content="The solar energy system in modern homes helps balance electricity demand.", metadata={"source": "I1"}),
    Document(page_content="Python balances readability with power, making it a popular system design language.", metadata={"source": "I2"}),
    Document(page_content="Photosynthesis enables plants to produce energy by converting sunlight.", metadata={"source": "I3"}),
    Document(page_content="The 2022 FIFA World Cup was held in Qatar and drew global energy and excitement.", metadata={"source": "I4"}),
    Document(page_content="Black holes bend spacetime and store immense gravitational energy.", metadata={"source": "I5"}),
]

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
    model_kwargs={"device": "cpu"},
    encode_kwargs={"normalize_embeddings": True},
)

vectorstore = FAISS.from_documents(
    documents=all_docs,
    embedding=embedding_model,
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
# %pip install -qU langchain-classic

# %%
from langchain_huggingface import HuggingFacePipeline, ChatHuggingFace
from langchain_classic.retrievers.multi_query import MultiQueryRetriever

# %%
from langchain_huggingface import HuggingFacePipeline, ChatHuggingFace
from langchain_classic.retrievers.multi_query import MultiQueryRetriever

base_llm = HuggingFacePipeline.from_model_id(
    model_id="Qwen/Qwen2.5-0.5B-Instruct",
    task="text-generation",
    pipeline_kwargs={"max_new_tokens": 128, "do_sample": False},
)

llm = ChatHuggingFace(llm=base_llm)

multiquery_retriever = MultiQueryRetriever.from_llm(
    retriever=vectorstore.as_retriever(search_kwargs={"k": 5}),
    llm=llm,
)
# Out:
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  988MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens', 'do_sample'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.

# %%
# Create retrievers
similarity_retriever = vectorstore.as_retriever(search_type = 'similarity', search_kwargs = {'k': 5})

# %%
# Query
query = "How to improve energy levels and maintain balance?"

# %%
# Retrieve Results
similarity_results = similarity_retriever.invoke(query)
multiquery_results = multiquery_retriever.invoke(query)
# Out:
# [transformers] The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [transformers] Both `max_new_tokens` (=128) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer Qwen2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.

# %%
for i, doc in enumerate(similarity_results):
  print(f"\n--- Result {i+1} ---")
  print(f"content:\n{doc.page_content}...")

print("+"*150)

for i, doc in enumerate(multiquery_results):
    print(f"\n--- Result {i+1} ---")
    print(f"content:\n{doc.page_content}...")
# Out:
# --- Result 1 ---
# content:
# Drinking sufficient water throughout the day helps maintain metabolism and energy....
#
# --- Result 2 ---
# content:
# The solar energy system in modern homes helps balance electricity demand....
#
# --- Result 3 ---
# content:
# Consuming leafy greens and fruits helps detox the body and improve longevity....
#
# --- Result 4 ---
# content:
# Mindfulness and controlled breathing lower cortisol and improve mental clarity....
#
# --- Result 5 ---
# content:
# Photosynthesis enables plants to produce energy by converting sunlight....
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# --- Result 1 ---
# content:
# Python balances readability with power, making it a popular system design language....
#
# --- Result 2 ---
# content:
# The solar energy system in modern homes helps balance electricity demand....
#
# --- Result 3 ---
# content:
# ...
